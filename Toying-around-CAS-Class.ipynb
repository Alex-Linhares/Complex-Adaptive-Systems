# %% [markdown]
# # Trying out Jupyter...
#
# ## First, I will check out if I can run some math.  Then, I will try out some matplotlib thing.

# %%
a = 107
b = a+1 
c = b+1

# %%
delta = []
delta.append(b**2-a**2)
delta.append(c**2-b**2)
print (delta)
# Out:
# [215, 217]

# %% [markdown]
# ### Então a matemática [funciona](https://www.youtube.com/watch?v=Rc4JQWowG5I)...
#
# $$f(x) = x^3 - \sqrt[5]{x^3} $$

# %%
print (delta)
# Out:
# [215, 217]

# %%
delta
# Out:
# [215, 217]

# %%
c
c**2
# Out:
# 11881

# %%
c**2
# Out:
# 11881

# %% [markdown]
# # Let's look at what the future of science looks like.
#
# [JupyterLab](https://www.youtube.com/watch?v=Ejh0ftSjk6g)
#
# And now let's follow [Jake](https://jakevdp.github.io/blog/2017/03/03/reproducible-data-analysis-in-jupyter/)
#
#
# https://github.com/jakevdp

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("https://www.youtube.com/watch?v=Ejh0ftSjk6g")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Ejh0ftSjk6g"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
URL = "https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD"
from urllib.request import urlretrieve

# %%
urlretrieve(URL, "Freemont.csv")
# Out:
# ('Freemont.csv', <http.client.HTTPMessage at 0x14d84fd0080>)

# %%
import pandas as pd
data = pd.read_csv("Freemont.csv", index_col = "Date", parse_dates = True)
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
# %matplotlib inline

# %%
data.plot()

# %%
data.resample('W').sum().plot()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

data.columns = ['West', "East"]
data.resample('W').sum().plot()

# %%
data.resample('D').sum().rolling(365).sum().plot()

# %%
data ['Total'] = data ['West'] + data ['East']
ax = data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0, None)
# Out:
# (0, 1059460.05)

# %%
data.groupby(data.index.time).mean().plot()

# %%
pivoted = data.pivot_table("Total", index = data.index.time, columns= data.index.date)

# %%
pivoted.iloc[:5,:5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend = False, alpha = 0.05)

# %% [markdown]
# ## [Now let's separate this data...](https://www.youtube.com/watch?v=n1qKe0kkwyU)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("https://www.youtube.com/watch?v=n1qKe0kkwyU")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=n1qKe0kkwyU"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
